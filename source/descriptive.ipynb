# %% [markdown]
# # Descriptive Analysis of the datasets

# %% [markdown]
# ## Imports

# %%
pip install -r "../requirements.txt"
# Out:
# Requirement already satisfied: pandas in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: dotenv in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (0.9.9)
# Requirement already satisfied: ucimlrepo in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (0.0.7)
# Requirement already satisfied: matplotlib in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (3.10.7)
# Requirement already satisfied: seaborn in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: plotly in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 6)) (6.3.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from -r ../requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: numpy>=1.26.0 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: python-dotenv in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from dotenv->-r ../requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: certifi>=2020.12.5 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from ucimlrepo->-r ../requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from plotly->-r ../requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from nbformat>=4.2.0->-r ../requirements.txt (line 7)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from nbformat>=4.2.0->-r ../requirements.txt (line 7)) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from nbformat>=4.2.0->-r ../requirements.txt (line 7)) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from nbformat>=4.2.0->-r ../requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r ../requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r ../requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r ../requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r ../requirements.txt (line 7)) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->-r ../requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: six>=1.5 in /Users/wuba/184.702_MachineLearning/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns

load_dotenv()
# Out:
# False

# %% [markdown]
# ## Dataset 1: UJIIndoorLoc
# QUOTE:
# """
# Many real world applications need to know the localization of a user in the world to provide their services. Therefore, automatic user localization has been a hot research topic in the last years. Automatic user localization consists of estimating the position of the user (latitude, longitude and altitude) by using an electronic device, usually a mobile phone. Outdoor localization problem can be solved very accurately thanks to the inclusion of GPS sensors into the mobile devices. However, indoor localization is still an open problem mainly due to the loss of GPS signal in indoor environments. Although, there are some indoor positioning technologies and methodologies, this database is focused on WLAN fingerprint-based ones (also know as WiFi Fingerprinting).
#
# Although there are many papers in the literature trying to solve the indoor localization problem using a WLAN fingerprint-based method, there still exists one important drawback in this field which is the lack of a common database for comparison purposes. So, UJIIndoorLoc database is presented to overcome this gap. We expect that the proposed database will become the reference database to compare different indoor localization methodologies based on WiFi fingerprinting.
#
# The UJIIndoorLoc database covers three buildings of Universitat Jaume I with 4 or more floors and almost 110.000m2. It can be used for classification, e.g. actual building and floor identification, or regression, e.g. actual longitude and latitude estimation. It was created in 2013 by means of more than 20 different users and 25 Android devices. The database consists of 19937 training/reference records (trainingData.csv file) and 1111 validation/test records (validationData.csv file).
#
# The 529 attributes contain the WiFi fingerprint, the coordinates where it was taken, and other useful information.
#
# Each WiFi fingerprint can be characterized by the detected Wireless Access Points (WAPs) and the corresponding Received Signal Strength Intensity (RSSI). The intensity values are represented as negative integer values ranging -104dBm (extremely poor signal) to 0dbM. The positive value 100 is used to denote when a WAP was not detected. During the database creation, 520 different WAPs were detected. Thus, the WiFi fingerprint is composed by 520 intensity values.
#
# Then the coordinates (latitude, longitude, floor) and Building ID are provided as the attributes to be predicted.
#
# Additional information has been provided.
#
# The particular space (offices, labs, etc.) and the relative position (inside/outside the space) where the capture was taken have been recorded. Outside means that the capture was taken in front of the door of the space.
#
# Information about who (user), how (android device & version) and when (timestamp) WiFi capture was taken is also recorded."""

# %%
folder_path = '../datasets/UJIndoorLoc/'
UJI_training_file = folder_path + 'trainingData.csv'
UJI_validation_file = folder_path + 'validationData.csv'
UJI_training = pd.read_csv(UJI_training_file)
UJI_validation = pd.read_csv(UJI_validation_file)
UJI_training.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 2       2       23  1371713733
# 1                 2       2       23  1371713691
# 2                 2       2       23  1371714095
# 3                 2       2       23  1371713807
# 4                 2      11       13  1369909710
#
# [5 rows x 529 columns]

# %%
UJI_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19937 entries, 0 to 19936
# Columns: 529 entries, WAP001 to TIMESTAMP
# dtypes: float64(2), int64(527)
# memory usage: 80.5 MB

# %%
UJI_training.shape
# Out:
# (19937, 529)

# %%
UJI_validation.shape
# Out:
# (1111, 529)

# %%
UJI_training["PHONEID"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='PHONEID'>

# %%
#Nr of Wifi Access Points
WAP_columns = [col for col in UJI_training.columns if col.startswith('WAP')]
print("There are", len(WAP_columns), "Wifi Access Points")
# Out:
# There are 520 Wifi Access Points

# %%
# Building and floor distribution with grouped barplot
# Collect unique buildings and floors and counts per (BUILDINGID, FLOOR)
building_counts = UJI_training['BUILDINGID'].unique()
floors_per_building = UJI_training.groupby('BUILDINGID')['FLOOR'].unique()

# Count entries per floor per building
floor_counts = UJI_training.groupby(['BUILDINGID', 'FLOOR']).size()

# Build nested dict (original structure)
floor_counts_dict = {}
for building in floor_counts.index.levels[0]:
    floor_counts_dict[building] = {}
    for floor in floor_counts[building].index:
        count = floor_counts[building][floor]
        floor_counts_dict[building][floor] = int(count)  # cast to int for JSON friendliness

# Convert to tidy DataFrame for plotting
records = [
    {"BUILDINGID": b, "FLOOR": f, "count": c}
    for b, floors in floor_counts_dict.items()
    for f, c in floors.items()
]
floor_df = pd.DataFrame(records)

# Ensure proper ordering
floor_df['BUILDINGID'] = floor_df['BUILDINGID'].astype(int)
floor_df['FLOOR'] = floor_df['FLOOR'].astype(int)

# Grouped barplot: floors on x-axis, separate bars per building
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=floor_df, x='BUILDINGID', y='count', hue='FLOOR', palette='tab10')
ax.set_title('Number of Samples per Floor and Building')
ax.set_xlabel('Building ID')
ax.set_ylabel('Sample Count')

# Annotate each bar with its count
for container in ax.containers:
    ax.bar_label(container, padding=2, fontsize=8)

# Optional: show legend title
ax.legend(title='Floor', frameon=True)
plt.tight_layout()
plt.show()

# Display the original dict if still desired
floor_counts_dict
# Out:
# {0: {0: 1059, 1: 1356, 2: 1443, 3: 1391},
#  1: {0: 1368, 1: 1484, 2: 1396, 3: 948},
#  2: {0: 1942, 1: 2162, 2: 1577, 3: 2709, 4: 1102}}

# %%
print("There are", UJI_training["SPACEID"].nunique(), "unique space IDs.")
# Out:
# There are 123 unique space IDs.

# %%
unique_spaces_per_building = UJI_training.groupby(['BUILDINGID'])['SPACEID'].nunique()
#barplot
unique_spaces_per_building.plot(kind='bar', figsize=(8, 5))
plt.title('Number of Unique Spaces per Building')
# Out:
# Text(0.5, 1.0, 'Number of Unique Spaces per Building')

# %%
UJI_training_positions_df = UJI_training[['BUILDINGID', 'LONGITUDE', 'LATITUDE', 'FLOOR', 'SPACEID']]

# %%
unique_spaces_per_building = UJI_training_positions_df.groupby('BUILDINGID')["SPACEID"].unique()

# %%
spaces_dict = {}
for bID, spaces in unique_spaces_per_building.items():
    for space in spaces:
        if space not in spaces_dict.keys():
            spaces_dict[space] = []
        spaces_dict[space].append(bID)
print(spaces_dict)
# Out:
# {np.int64(122): [0, 1, 2], np.int64(102): [0, 1, 2], np.int64(110): [0, 1, 2], np.int64(111): [0, 1, 2], np.int64(107): [0, 1, 2], np.int64(106): [0, 1, 2], np.int64(115): [0, 1, 2], np.int64(114): [0, 1, 2], np.int64(113): [0, 1, 2], np.int64(112): [0, 1, 2], np.int64(116): [0, 1, 2], np.int64(120): [0, 2], np.int64(119): [0, 1, 2], np.int64(117): [0, 1, 2], np.int64(118): [0, 1, 2], np.int64(121): [0, 1, 2], np.int64(123): [0, 2], np.int64(125): [0, 2], np.int64(126): [0, 2], np.int64(129): [0, 2], np.int64(127): [0, 2], np.int64(128): [0, 2], np.int64(133): [0, 2], np.int64(131): [0, 2], np.int64(130): [0, 2], np.int64(134): [0, 2], np.int64(132): [0, 2], np.int64(236): [0, 2], np.int64(201): [0, 1, 2], np.int64(208): [0, 1, 2], np.int64(202): [0, 1, 2], np.int64(212): [0, 1, 2], np.int64(214): [0, 1, 2], np.int64(209): [0, 1, 2], np.int64(211): [0, 1, 2], np.int64(213): [0, 1, 2], np.int64(237): [0, 1, 2], np.int64(216): [0, 1, 2], np.int64(215): [0, 1, 2], np.int64(218): [0, 1, 2], np.int64(234): [0, 2], np.int64(220): [0, 1, 2], np.int64(219): [0, 1, 2], np.int64(235): [0, 1, 2], np.int64(233): [0, 2], np.int64(231): [0, 1, 2], np.int64(232): [0, 2], np.int64(230): [0, 1, 2], np.int64(222): [0, 1, 2], np.int64(225): [0, 1, 2], np.int64(229): [0, 1, 2], np.int64(227): [0, 1, 2], np.int64(224): [0, 1, 2], np.int64(210): [0, 1, 2], np.int64(205): [0, 1, 2], np.int64(206): [0, 1, 2], np.int64(204): [0, 1, 2], np.int64(207): [0, 1, 2], np.int64(203): [0, 1, 2], np.int64(217): [0, 1, 2], np.int64(221): [0, 2], np.int64(226): [0, 1, 2], np.int64(223): [0, 2], np.int64(228): [0, 1, 2], np.int64(138): [0, 2], np.int64(101): [0, 1, 2], np.int64(124): [0, 2], np.int64(103): [0, 1, 2], np.int64(105): [0, 1, 2], np.int64(109): [0, 1, 2], np.int64(108): [0, 1, 2], np.int64(140): [0, 2], np.int64(139): [0, 2], np.int64(104): [0, 1, 2], np.int64(241): [0, 2], np.int64(137): [0, 2], np.int64(135): [0, 2], np.int64(136): [0, 2], np.int64(15): [1], np.int64(29): [1], np.int64(16): [1], np.int64(28): [1], np.int64(22): [1], np.int64(10): [1], np.int64(2): [1], np.int64(4): [1], np.int64(3): [1], np.int64(5): [1], np.int64(6): [1], np.int64(9): [1], np.int64(27): [1], np.int64(8): [1], np.int64(7): [1], np.int64(26): [1], np.int64(18): [1], np.int64(17): [1], np.int64(248): [1, 2], np.int64(247): [1, 2], np.int64(244): [1, 2], np.int64(243): [1, 2], np.int64(245): [1, 2], np.int64(246): [1, 2], np.int64(249): [1], np.int64(238): [1, 2], np.int64(239): [1, 2], np.int64(1): [1], np.int64(30): [1], np.int64(25): [1], np.int64(13): [1], np.int64(12): [1], np.int64(11): [1], np.int64(14): [1], np.int64(242): [2], np.int64(240): [2], np.int64(250): [2], np.int64(141): [2], np.int64(143): [2], np.int64(253): [2], np.int64(254): [2], np.int64(142): [2], np.int64(146): [2], np.int64(147): [2], np.int64(144): [2]}

# %%
unique_spaces_per_building[0]
# Out:
# array([122, 102, 110, 111, 107, 106, 115, 114, 113, 112, 116, 120, 119,
#        117, 118, 121, 123, 125, 126, 129, 127, 128, 133, 131, 130, 134,
#        132, 236, 201, 208, 202, 212, 214, 209, 211, 213, 237, 216, 215,
#        218, 234, 220, 219, 235, 233, 231, 232, 230, 222, 225, 229, 227,
#        224, 210, 205, 206, 204, 207, 203, 217, 221, 226, 223, 228, 138,
#        101, 124, 103, 105, 109, 108, 140, 139, 104, 241, 137, 135, 136])

# %%
unique_spaces_per_building[1]
# Out:
# array([106, 103, 102, 105, 101, 112, 104, 110, 108, 109, 111, 107,  15,
#         29, 117,  16,  28,  22,  10,   2,   4,   3,   5,   6,   9,  27,
#          8,   7,  26,  18, 216,  17, 217, 202, 203, 248, 247, 222, 213,
#        244, 243, 245, 246, 249, 237, 227, 228, 230, 229, 238, 231, 235,
#        239, 215, 210, 209, 201, 207, 208, 204, 206, 205, 116, 113, 211,
#        212, 214, 115, 121, 119, 118, 122, 114,   1,  30,  25,  13,  12,
#        218, 219, 220, 225, 224, 226,  11,  14])

# %%
unique_spaces_per_building[2]
# Out:
# array([247, 248, 246, 245, 244, 243, 242, 241, 240, 201, 202, 204, 203,
#        205, 207, 206, 209, 211, 208, 210, 212, 214, 213, 216, 217, 215,
#        121, 219, 221, 222, 218, 220, 250, 223, 225, 224, 229, 226, 227,
#        228, 233, 231, 230, 232, 236, 235, 234, 237, 238, 239, 141, 102,
#        140, 143, 101, 103, 105, 111, 106, 104, 108, 107, 112, 113, 109,
#        114, 116, 117, 115, 110, 120, 118, 128, 119, 129, 122, 125, 124,
#        131, 127, 132, 126, 133, 134, 137, 135, 136, 253, 254, 123, 130,
#        138, 139, 142, 146, 147, 144])

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(
    UJI_training_positions_df['LONGITUDE'],
    UJI_training_positions_df['LATITUDE'],
    UJI_training_positions_df['FLOOR'],
    c=UJI_training_positions_df['FLOOR'],
    
)

# %%
import plotly.express as px
fig = px.scatter_3d(
    UJI_training_positions_df,
    x='LONGITUDE',
    y='LATITUDE',
    z='FLOOR',
    color='BUILDINGID',
    title='3D Scatter Plot of Positions Colored by Floor',
)
fig.update_traces(marker = dict(size=4))
fig.show()

# %% [markdown]
# ## Dataset 2: Myocardial infarction complications

# %% [markdown]
# ### Summary
# QUOTE:
# "Problems of real-life complexity are needed to test and compare various data mining and pattern recognition methods. The proposed database can be used to solve two practically important problems: predicting complications of Myocardial Infarction (MI) based on information about the patient (i) at the time of admission and (ii) on the third day of the hospital period. Another important group of tasks is phenotyping of disease (cluster analysis), dynamic phenotyping (filament extraction and identification of disease trajectories) and visualisation (disease mapping).
# MI is one of the most challenging problems of modern medicine. Acute myocardial infarction is associated with high mortality in the first year after it. The incidence of MI remains high in all countries. This is especially true for the urban population of highly developed countries, which is exposed to chronic stress factors, irregular and not always balanced nutrition. In the United States, for example, more than a million people suffer from MI every year, and 200-300 thousand of them die from acute MI before arriving at the hospital.
# The course of the disease in patients with MI is different. MI can occur without complications or with complications that do not worsen the long-term prognosis. At the same time, about half of patients in the acute and subacute periods have complications that lead to worsening of the disease and even death. Even an experienced specialist can not always foresee the development of these complications. In this regard, predicting complications of myocardial infarction in order to timely carry out the necessary preventive measures is an important task.
#
# Problems to solve
# In general columns 2-112 can be used as input data for prediction. Possible complications (outputs) are listed in columns 113-124.
# There are four possible time moments for complication prediction: on base of the information known at
# 1.	the time of admission to hospital: all input columns (2-112) except 93, 94, 95, 100, 101, 102, 103, 104, 105 can be used for prediction;
# 2.	the end of the first day (24 hours after admission to the hospital): all input columns (2-112) except 94, 95, 101, 102, 104, 105 can be used for prediction;
# 3.	the end of the second day (48 hours after admission to the hospital) all input columns (2-112) except 95, 102, 105 can be used for prediction;
# 4.	the end of the third day (72 hours after admission to the hospital) all input columns (2-112) can be used for prediction.
#
# You can find detailed description of database, descriptive statistics and csv version of database in DOI: 10.25392/leicester.data.12045261.v3 " (Source)[https://archive.ics.uci.edu/dataset/579/myocardial+infarction+complications]

# %%
from ucimlrepo import fetch_ucirepo 

# fetch dataset
mi_complications = fetch_ucirepo(id=579)

# data (as pandas dataframes)
mi_features = mi_complications.data.features
mi_targets = mi_complications.data.targets

mi_metadata = mi_complications.metadata
mi_variables = mi_complications.variables

# %%
print(mi_metadata.additional_info.summary)
# Out:
# Problems of real-life complexity are needed to test and compare various data mining and pattern recognition methods. The proposed database can be used to solve two practically important problems: predicting complications of Myocardial Infarction (MI) based on information about the patient (i) at the time of admission and (ii) on the third day of the hospital period. Another important group of tasks is phenotyping of disease (cluster analysis), dynamic phenotyping (filament extraction and identification of disease trajectories) and visualisation (disease mapping).
# MI is one of the most challenging problems of modern medicine. Acute myocardial infarction is associated with high mortality in the first year after it. The incidence of MI remains high in all countries. This is especially true for the urban population of highly developed countries, which is exposed to chronic stress factors, irregular and not always balanced nutrition. In the United States, for example, more than a million people suffer from MI every year, and 200-300 thousand of them die from acute MI before arriving at the hospital.
# The course of the disease in patients with MI is different. MI can occur without complications or with complications that do not worsen the long-term prognosis. At the same time, about half of patients in the acute and subacute periods have complications that lead to worsening of the disease and even death. Even an experienced specialist can not always foresee the development of these complications. In this regard, predicting complications of myocardial infarction in order to timely carry out the necessary preventive measures is an important task.
#
# Problems to solve
# In general columns 2-112 can be used as input data for prediction. Possible complications (outputs) are listed in columns 113-124.
# There are four possible time moments for complication prediction: on base of the information known at
# 1.	the time of admission to hospital: all input columns (2-112) except 93, 94, 95, 100, 101, 102, 103, 104, 105 can be used for prediction;
# 2.	the end of the first day (24 hours after admission to the hospital): all input columns (2-112) except 94, 95, 101, 102, 104, 105 can be used for prediction;
# 3.	the end of the second day (48 hours after admission to the hospital) all input columns (2-112) except 95, 102, 105 can be used for prediction;
# 4.	the end of the third day (72 hours after admission to the hospital) all input columns (2-112) can be used for prediction.
#
# You can find detailed description of database, descriptive statistics and csv version of database in DOI: 10.25392/leicester.data.12045261.v3

# %%
print(f"""
Dataset Name:          {mi_metadata.name}
Abstract:              {mi_metadata.abstract}
Area:                  {mi_metadata.area}
Task:                  {mi_metadata.tasks[0]}
Last updated:          {mi_metadata.last_updated}
Has missing values:    {mi_metadata.has_missing_values}
Number of Instances:   {mi_metadata.num_instances}
Number of Features:    {mi_metadata.num_features}
Number of Targets:     {len(mi_metadata.target_col)}
""")
# Out:
# Dataset Name:          Myocardial infarction complications
# Abstract:              Prediction of myocardial infarction complications
# Area:                  Health and Medicine
# Task:                  Classification
# Last updated:          Fri Nov 03 2023
# Has missing values:    yes
# Number of Instances:   1700
# Number of Features:    111
# Number of Targets:     12

# %% [markdown]
# ### Target Variables

# %%
mi_variables
# Out:
#           name     role         type demographic  \
# 0           ID       ID      Integer        None
# 1          AGE  Feature      Integer         Age
# 2          SEX  Feature       Binary         Sex
# 3     INF_ANAM  Feature  Categorical        None
# 4    STENOK_AN  Feature  Categorical        None
# ..         ...      ...          ...         ...
# 119   DRESSLER   Target       Binary        None
# 120        ZSN   Target       Binary        None
# 121     REC_IM   Target       Binary        None
# 122  P_IM_STEN   Target       Binary        None
# 123     LET_IS   Target  Categorical        None
#
#                                            description units missing_values
# 0    Record ID (ID): Unique identifier. Cannot be r...  None             no
# 1                                      Age of patient.  None             no
# 2                                   0: female, 1: male  None             no
# 3    Quantity of myocardial infarctions in the anam...  None            yes
# 4    Exertional angina pectoris in the anamnesis. \...  None            yes
# ..                                                 ...   ...            ...
# 119                                  Dressler syndrome  None             no
# 120                              Chronic heart failure  None             no
# 121               Relapse of the myocardial infarction  None             no
# 122                             Post-infarction angina  None             no
# 123  Lethal outcome (cause)\n\n0: unknown (alive)\n...  None             no
#
# [124 rows x 7 columns]

# %%
mi_target_variables = mi_variables[mi_variables['role'].str.lower() == 'target'].copy()
mi_target_variables.set_index('name', inplace=True)

# %%
mi_target_variables
# Out:
#               role         type demographic  \
# name
# FIBR_PREDS  Target       Binary        None
# PREDS_TAH   Target       Binary        None
# JELUD_TAH   Target       Binary        None
# FIBR_JELUD  Target       Binary        None
# A_V_BLOK    Target       Binary        None
# OTEK_LANC   Target       Binary        None
# RAZRIV      Target       Binary        None
# DRESSLER    Target       Binary        None
# ZSN         Target       Binary        None
# REC_IM      Target       Binary        None
# P_IM_STEN   Target       Binary        None
# LET_IS      Target  Categorical        None
#
#                                                   description units  \
# name
# FIBR_PREDS                                Atrial fibrillation  None
# PREDS_TAH                        Supraventricular tachycardia  None
# JELUD_TAH                             Ventricular tachycardia  None
# FIBR_JELUD                           Ventricular fibrillation  None
# A_V_BLOK                                Third-degree AV block  None
# OTEK_LANC                                     Pulmonary edema  None
# RAZRIV                                    Myocardial rupture   None
# DRESSLER                                    Dressler syndrome  None
# ZSN                                     Chronic heart failure  None
# REC_IM                   Relapse of the myocardial infarction  None
# P_IM_STEN                              Post-infarction angina  None
# LET_IS      Lethal outcome (cause)\n\n0: unknown (alive)\n...  None
#
#            missing_values
# name
# FIBR_PREDS             no
# PREDS_TAH              no
# JELUD_TAH              no
# FIBR_JELUD             no
# A_V_BLOK               no
# OTEK_LANC              no
# RAZRIV                 no
# DRESSLER               no
# ZSN                    no
# REC_IM                 no
# P_IM_STEN              no
# LET_IS                 no

# %%
mi_target_variables["count"] = 0
for i in mi_target_variables.index:
    if mi_target_variables.loc[i, "type"].lower() == 'binary':
        mi_target_variables.loc[i, "count"] = mi_targets[i].sum()
    else:
        mi_target_variables.loc[i, "count"] = mi_targets[i].count()

# %%
mi_target_variables
# Out:
#               role         type demographic  \
# name
# FIBR_PREDS  Target       Binary        None
# PREDS_TAH   Target       Binary        None
# JELUD_TAH   Target       Binary        None
# FIBR_JELUD  Target       Binary        None
# A_V_BLOK    Target       Binary        None
# OTEK_LANC   Target       Binary        None
# RAZRIV      Target       Binary        None
# DRESSLER    Target       Binary        None
# ZSN         Target       Binary        None
# REC_IM      Target       Binary        None
# P_IM_STEN   Target       Binary        None
# LET_IS      Target  Categorical        None
#
#                                                   description units  \
# name
# FIBR_PREDS                                Atrial fibrillation  None
# PREDS_TAH                        Supraventricular tachycardia  None
# JELUD_TAH                             Ventricular tachycardia  None
# FIBR_JELUD                           Ventricular fibrillation  None
# A_V_BLOK                                Third-degree AV block  None
# OTEK_LANC                                     Pulmonary edema  None
# RAZRIV                                    Myocardial rupture   None
# DRESSLER                                    Dressler syndrome  None
# ZSN                                     Chronic heart failure  None
# REC_IM                   Relapse of the myocardial infarction  None
# P_IM_STEN                              Post-infarction angina  None
# LET_IS      Lethal outcome (cause)\n\n0: unknown (alive)\n...  None
#
#            missing_values  count
# name
# FIBR_PREDS             no    170
# PREDS_TAH              no     20
# JELUD_TAH              no     42
# FIBR_JELUD             no     71
# A_V_BLOK               no     57
# OTEK_LANC              no    159
# RAZRIV                 no     54
# DRESSLER               no     75
# ZSN                    no    394
# REC_IM                 no    159
# P_IM_STEN              no    148
# LET_IS                 no   1700

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8, 4))
data = mi_target_variables[mi_target_variables["type"].str.lower() == "binary"].sort_values(by="count", ascending=False)
ax = sns.barplot(x="count", y="description", data=data, orient="h")
ax.set_title("Occurence of Target Variables to be True")
ax.set_xlabel("Count")
ax.set_ylabel("Target Variables")
abs_values = data["count"].values
ax.bar_label(container=ax.containers[0], labels=abs_values)
plt.show()

# %%
LET_IS_MAPPING = {
    0: "unknonw (alive)",
    1: "cardiogenic shock",
    2: "pulmonary edema",
    3: "myocardial rupture",
    4: "progress of congestive heart failure",
    5: "thromboembolism",
    6: "asystole",
    7: "ventricular fibrillation"
}
plt.figure(figsize=(8, 4))
ax = sns.countplot(data=mi_targets, y='LET_IS', order=mi_targets['LET_IS'].value_counts().index)
ax.set_yticks(ticks=list(LET_IS_MAPPING.keys()), labels=list(LET_IS_MAPPING.values()), ha='right')
ax.set_title('Distribution of lethal outcome cause (LET_IS)')
ax.set_ylabel('Lethal outcome cause')
ax.set_xlabel('Count')
ax.set_xlim(0, 1600)
abs_values = mi_targets['LET_IS'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=abs_values)
plt.show()

# %%
LET_IS_encoded = pd.get_dummies(mi_targets['LET_IS'], prefix='LET_IS')

# %%
LET_IS_encoded
# Out:
#       LET_IS_0  LET_IS_1  LET_IS_2  LET_IS_3  LET_IS_4  LET_IS_5  LET_IS_6  \
# 0         True     False     False     False     False     False     False
# 1         True     False     False     False     False     False     False
# 2         True     False     False     False     False     False     False
# 3         True     False     False     False     False     False     False
# 4         True     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 1695     False     False     False      True     False     False     False
# 1696     False      True     False     False     False     False     False
# 1697     False     False     False     False     False     False      True
# 1698     False      True     False     False     False     False     False
# 1699     False      True     False     False     False     False     False
#
#       LET_IS_7
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 1695     False
# 1696     False
# 1697     False
# 1698     False
# 1699     False
#
# [1700 rows x 8 columns]

# %% [markdown]
# ### Features

# %%
mi_feature_variables = mi_variables[mi_variables['role'].str.lower() == 'feature']
mi_feature_variables.set_index('name', inplace=True)

# %%
mi_feature_variables
# Out:
#                role         type demographic  \
# name
# AGE         Feature      Integer         Age
# SEX         Feature       Binary         Sex
# INF_ANAM    Feature  Categorical        None
# STENOK_AN   Feature  Categorical        None
# FK_STENOK   Feature  Categorical        None
# ...             ...          ...         ...
# ANT_CA_S_n  Feature       Binary        None
# GEPAR_S_n   Feature       Binary        None
# ASP_S_n     Feature       Binary        None
# TIKL_S_n    Feature       Binary        None
# TRENT_S_n   Feature       Binary        None
#
#                                                   description units  \
# name
# AGE                                           Age of patient.  None
# SEX                                        0: female, 1: male  None
# INF_ANAM    Quantity of myocardial infarctions in the anam...  None
# STENOK_AN   Exertional angina pectoris in the anamnesis. \...  None
# FK_STENOK   Functional class (FC) of angina pectoris in th...  None
# ...                                                       ...   ...
# ANT_CA_S_n         Use of calcium channel blockers in the ICU  None
# GEPAR_S_n        Use of а anticoagulants (heparin) in the ICU  None
# ASP_S_n               Use of acetylsalicylic acid in the ICU   None
# TIKL_S_n                             Use of Ticlid in the ICU  None
# TRENT_S_n                           Use of Trental in the ICU  None
#
#            missing_values
# name
# AGE                    no
# SEX                    no
# INF_ANAM              yes
# STENOK_AN             yes
# FK_STENOK             yes
# ...                   ...
# ANT_CA_S_n            yes
# GEPAR_S_n             yes
# ASP_S_n               yes
# TIKL_S_n              yes
# TRENT_S_n             yes
#
# [111 rows x 6 columns]

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(10,6))
#label the boxes
sns.countplot(data=mi_feature_variables, x='type', ax=axs[0], order=mi_feature_variables['type'].value_counts().index)
axs[0].set_xlabel('Feature Type')
axs[0].set_ylabel('Count')
axs[0].set_title('Distribution of Feature Types')
sns.countplot(data=mi_feature_variables, x='missing_values', ax=axs[1], order=mi_feature_variables['missing_values'].value_counts().index)
axs[1].set_xlabel('Missing Values')
axs[1].set_ylabel('Count')
axs[1].set_title('Features with Missing Values')

plt.show()

# %%
mi_feature_variables[mi_feature_variables["type"] == "Continuous"]
# Out:
#               role        type demographic  \
# name
# K_BLOOD    Feature  Continuous        None
# NA_BLOOD   Feature  Continuous        None
# ALT_BLOOD  Feature  Continuous        None
# AST_BLOOD  Feature  Continuous        None
# KFK_BLOOD  Feature  Continuous        None
# L_BLOOD    Feature  Continuous        None
# ROE        Feature  Continuous        None
#
#                                     description               units  \
# name
# K_BLOOD                 Serum potassium content              mmol/L
# NA_BLOOD                   Serum sodium content              mmol/L
# ALT_BLOOD        Serum AlAT content (ALT_BLOOD)                IU/L
# AST_BLOOD                    Serum AsAT content                IU/L
# KFK_BLOOD                     Serum CPK content                IU/L
# L_BLOOD                 White blood cell count   billions per liter
# ROE        ESR (Erythrocyte sedimentation rate)                  мм
#
#           missing_values
# name
# K_BLOOD              yes
# NA_BLOOD             yes
# ALT_BLOOD            yes
# AST_BLOOD            yes
# KFK_BLOOD            yes
# L_BLOOD              yes
# ROE                  yes

# %%
plt.hist(mi_features["AGE"])
# Out:
# (array([  7.,  48., 104., 189., 261., 464., 314., 197.,  93.,  15.]),
#  array([26. , 32.6, 39.2, 45.8, 52.4, 59. , 65.6, 72.2, 78.8, 85.4, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(data=mi_features, x='SEX')
# Out:
# <Axes: xlabel='SEX', ylabel='count'>
